# %%
import pandas as pd
import numpy as np
from scipy.stats import entropy

from pgmpy.models import BayesianModel
from pgmpy.estimators import HillClimbSearch, K2Score, BicScore
from pgmpy.sampling.Sampling import BayesianModelSampling
from pgmpy.factors.discrete.CPD import TabularCPD
from pgmpy.estimators import BayesianEstimator, ParameterEstimator, MaximumLikelihoodEstimator

def JSD(P, Q):
    _P = P / np.linalg.norm(P, ord=1)
    _Q = Q / np.linalg.norm(Q, ord=1)
    _M = 0.5 * (_P + _Q)
    return 0.5 * (entropy(_P, _M) + entropy(_Q, _M))

# %%
data = pd.DataFrame.from_csv('crash_sample_2018.csv', index_col=None)
data.drop(data.columns[0], axis=1, inplace=True)
nodes = list(data.columns)
cat_to_num = {'AvgSpeed' : {'low' :0, 'high':1}, \
              'Country' : {'US':0, 'UK':1, 'Europe':2}, \
              'DangerLvl' : {'low':0, 'high':1}, \
              'NoAccidents' : {'low':0, 'medium':1, 'high':2}, \
              'NoFatalities' : {'low':0, 'medium':1, 'high':2}, \
              'NoJourneys' : {'low':0, 'medium':1, 'high':2}, \
              'PoliceActivity' : {'regular':0, 'increased':1}, \
              'RoadCond' : {'bad':0,'good':1}, \
              'Season' : {'winter':0, 'spring':1, 'summer':2, 'fall':3}, \
              'Weather' : {'bad':0, 'good':1}, \
              'Weekend' : {'working':0, 'weekend':1, 'holiday':2},
             }

num_to_cat = {}
for k1,v1 in cat_to_num.items():
    num_to_cat[k1] = { v2 : k2 for k2, v2 in v1.items()}
# Out:
# /Users/ananias/miniconda3/envs/SMU/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   """Entry point for launching an IPython kernel.

# %%
# splitting data

# select rows with missing data only
test_data = data[data.isnull().any(axis=1)]

train_data = data.dropna(axis=0)
# get count of each combination in the data
# data.groupby(nodes).size()

# replace strings with numbers and back
# data = data.replace(num_to_cat).replace(cat_to_num)
# data.sort_values('NoJourneys', ascending=False)

connections = [('Weekend', 'NoJourneys'), ('Season', 'NoJourneys'), ('Weather', 'RoadCond'), ('RoadCond', 'NoFatalities'),
               ('PoliceActivity', 'NoFatalities'), ('NoJourneys', 'NoAccidents'), ('Country', 'NoFatalities'), ('AvgSpeed', 'NoFatalities'),
               ('DangerLvl', 'NoFatalities'), ('NoAccidents', 'NoFatalities')]

# %%
# def EM(data, iter=1000):
import time
data = test_data.head(100)
iters = 1

null_idx = pd.isnull(data)
predicting = [] #.copy()
filling = data[data.isnull().any(axis=1)] #data[null_idx].copy()
model = BayesianModel(connections)
# model.fit(predicting, estimator=MaximumLikelihoodEstimator)
it = 0

#predrop
na_removed = {}
for k,row in filling.iterrows():
    #if null
    na_removed[k] = row.dropna(axis=0).to_frame().T

while it < iters and not filling.equals(predicting):
    it += 1
    predicting = filling.copy()
    
    mle = MaximumLikelihoodEstimator(model,data)
    [model.add_cpds(cpd) for cpd in mle.get_parameters()]
    
    filling[null_idx] = np.nan
    t0 = time.clock()
    print('fit: ', time.clock() - t0)
    for k,v in filling.iterrows():
#         v.dropna(axis=0, inplace=True)
        t0 = time.clock()
        value = model.predict(na_removed[k])
        print(na_removed[k])
        print('predict: ', time.clock() - t0)

        for col_name in value.columns:
            filling.at[k, col_name] = value[col_name].values[0]
    print('iteration: ', it, time.clock() - t0)
                
filling
# Out:
# fit:  4.999999999810711e-06
#    Weekend Season Weather RoadCond PoliceActivity NoJourneys Country  \
# 0  holiday   fall    good     good        regular        low      UK
#
#   DangerLvl NoAccidents NoFatalities
# 0       low        high       medium
# predict:  0.128737000000001
#    Weekend Weather RoadCond PoliceActivity NoJourneys Country AvgSpeed  \
# 1  weekend     bad      bad        regular     medium  Europe      low
#
#   DangerLvl NoAccidents NoFatalities
# 1       low      medium          low
# predict:  0.143478
#    Weekend  Season RoadCond PoliceActivity NoJourneys Country DangerLvl  \
# 3  weekend  spring     good        regular     medium      UK       low
#
#   NoAccidents NoFatalities
# 3         low          low
# predict:  0.14496300000000062
#    Weekend  Season RoadCond PoliceActivity NoJourneys Country AvgSpeed  \
# 8  weekend  winter      bad        regular     medium      UK      low
#
#   DangerLvl NoAccidents NoFatalities
# 8       low         low         high
# predict:  0.1418569999999999
#    Weekend Season Weather RoadCond PoliceActivity NoJourneys Country AvgSpeed  \
# 9  weekend   fall    good      bad        regular        low  Europe      low
#
#   NoAccidents NoFatalities
# 9         low       medium
# predict:  0.13014100000000006
#     Weekend Season Weather RoadCond PoliceActivity NoJourneys Country  \
# 11  working   fall    good     good      increased     medium      US
#
#    AvgSpeed NoAccidents NoFatalities
# 11     high         low          low
# predict:  0.1472130000000007
#     Weekend  Season Weather RoadCond PoliceActivity NoJourneys Country  \
# 18  weekend  winter     bad      bad        regular        low      US
#
#    AvgSpeed NoAccidents NoFatalities
# 18      low      medium          low
# predict:  0.12686500000000045
#     Weekend  Season Weather RoadCond NoJourneys Country AvgSpeed DangerLvl  \
# 27  weekend  winter     bad      bad        low      UK      low       low
#
#    NoAccidents NoFatalities
# 27      medium         high
# predict:  0.1222840000000005
#     Weekend  Season Weather RoadCond PoliceActivity NoJourneys Country  \
# 31  weekend  summer    good     good        regular     medium      US
#
#    AvgSpeed DangerLvl NoFatalities
# 31      low       low          low
# predict:  0.1375460000000004
#     Weekend Season RoadCond PoliceActivity NoJourneys Country AvgSpeed  \
# 33  weekend   fall      bad        regular        low  Europe     high
#
#    DangerLvl NoAccidents NoFatalities
# 33       low         low          low
# predict:  0.13484100000000154
#     Weekend  Season Weather RoadCond PoliceActivity NoJourneys Country  \
# 37  working  spring    good     good        regular        low  Europe
#
#    AvgSpeed NoFatalities
# 37     high          low
# predict:  0.1243559999999988
#     Weekend  Season Weather RoadCond PoliceActivity NoJourneys Country  \
# 39  working  spring    good     good        regular     medium      UK
#
#    DangerLvl NoAccidents NoFatalities
# 39       low         low          low
# predict:  0.1285759999999989
#     Weekend  Season Weather RoadCond NoJourneys Country AvgSpeed DangerLvl  \
# 44  working  winter    good     good        low      US      low       low
#
#    NoAccidents NoFatalities
# 44         low          low
# predict:  0.19165999999999883
#     Weekend Season Weather RoadCond PoliceActivity Country AvgSpeed DangerLvl  \
# 45  working   fall     bad      bad        regular  Europe      low       low
#
#    NoFatalities
# 45          low
# predict:  0.1661910000000013
#    Season Weather RoadCond NoJourneys Country DangerLvl NoAccidents  \
# 48   fall     bad      bad        low      US       low         low
#
#    NoFatalities
# 48          low
# predict:  0.16222099999999884
#     Weekend Season Weather RoadCond PoliceActivity NoJourneys Country  \
# 49  working   fall     bad      bad        regular        low  Europe
#
#    AvgSpeed DangerLvl NoAccidents
# 49      low       low      medium
# predict:  0.12220900000000157
#     Weekend  Season Weather RoadCond PoliceActivity NoJourneys Country  \
# 51  weekend  summer    good     good        regular     medium  Europe
#
#    DangerLvl NoAccidents NoFatalities
# 51       low         low          low
# predict:  0.16666000000000025
#     Weekend  Season Weather RoadCond PoliceActivity Country NoAccidents  \
# 54  working  spring    good      bad        regular      US      medium
#
#    NoFatalities
# 54         high
# predict:  0.17645399999999967
#     Weekend Weather RoadCond PoliceActivity NoJourneys Country AvgSpeed  \
# 56  weekend     bad      bad        regular        low      US      low
#
#    DangerLvl NoAccidents NoFatalities
# 56       low         low          low
# predict:  0.16896299999999798
#     Weekend  Season Weather RoadCond PoliceActivity NoJourneys Country  \
# 58  working  summer    good     good        regular     medium      UK
#
#    AvgSpeed NoAccidents NoFatalities
# 58     high         low       medium
# predict:  0.1736779999999989
#     Weekend  Season Weather RoadCond NoJourneys Country AvgSpeed DangerLvl  \
# 60  holiday  winter    good      bad     medium  Europe      low       low
#
#    NoAccidents
# 60         low
# predict:  0.1385809999999985
#     Weekend Weather RoadCond PoliceActivity NoJourneys Country AvgSpeed  \
# 62  working    good     good        regular     medium  Europe     high
#
#    DangerLvl NoAccidents NoFatalities
# 62       low      medium          low
# predict:  0.12760699999999758
#     Weekend  Season Weather RoadCond PoliceActivity NoJourneys AvgSpeed  \
# 63  working  winter     bad      bad        regular        low      low
#
#    DangerLvl NoAccidents NoFatalities
# 63       low         low          low
# predict:  0.16380099999999942
#     Weekend  Season Weather RoadCond PoliceActivity NoJourneys Country  \
# 64  working  summer    good      bad        regular        low      US
#
#    AvgSpeed NoAccidents NoFatalities
# 64      low         low          low
# predict:  0.1352759999999975
#     Weekend  Season Weather RoadCond PoliceActivity NoJourneys Country  \
# 69  working  spring    good      bad        regular        low  Europe
#
#    AvgSpeed DangerLvl NoAccidents
# 69      low       low         low
# predict:  0.15123200000000026
#     Weekend Season Weather RoadCond PoliceActivity NoJourneys Country  \
# 70  holiday   fall    good     good        regular     medium      UK
#
#    AvgSpeed DangerLvl NoAccidents
# 70     high       low      medium
# predict:  0.15215500000000048
#     Weekend  Season Weather RoadCond PoliceActivity NoJourneys Country  \
# 72  working  summer    good     good        regular     medium      UK
#
#    AvgSpeed DangerLvl NoAccidents
# 72     high       low      medium
# predict:  0.19836499999999901
#     Weekend  Season Weather RoadCond PoliceActivity NoJourneys Country  \
# 76  working  winter     bad      bad        regular        low      US
#
#    DangerLvl NoAccidents NoFatalities
# 76       low         low       medium
# predict:  0.21448200000000028
#     Weekend  Season Weather RoadCond NoJourneys Country AvgSpeed DangerLvl  \
# 77  working  spring     bad      bad     medium  Europe      low       low
#
#    NoAccidents NoFatalities
# 77         low       medium
# predict:  0.16037999999999997
#     Weekend Season Weather RoadCond PoliceActivity NoJourneys Country  \
# 79  holiday   fall    good     good        regular     medium  Europe
#
#    AvgSpeed DangerLvl NoAccidents
# 79     high       low         low
# predict:  0.13055999999999912
#     Season Weather RoadCond PoliceActivity NoJourneys Country AvgSpeed  \
# 80  winter    good      bad        regular     medium  Europe      low
#
#    DangerLvl NoAccidents NoFatalities
# 80       low        high         high
# predict:  0.13835700000000273
#     Weekend  Season Weather RoadCond PoliceActivity Country AvgSpeed  \
# 82  weekend  spring     bad      bad        regular  Europe      low
#
#    DangerLvl NoAccidents NoFatalities
# 82       low         low       medium
# predict:  0.12876300000000285
#     Weekend Weather RoadCond PoliceActivity NoJourneys Country AvgSpeed  \
# 84  working     bad      bad        regular        low      US      low
#
#    DangerLvl NoAccidents NoFatalities
# 84       low      medium          low
# predict:  0.12785499999999672
#     Weekend  Season Weather RoadCond PoliceActivity Country AvgSpeed  \
# 88  working  winter    good      bad      increased  Europe      low
#
#    DangerLvl NoAccidents NoFatalities
# 88       low         low          low
# predict:  0.12578500000000048
#     Weekend  Season Weather RoadCond PoliceActivity NoJourneys Country  \
# 89  working  winter     bad      bad        regular     medium      US
#
#    AvgSpeed NoAccidents NoFatalities
# 89      low         low          low
# predict:  0.19879199999999742
#     Season Weather RoadCond PoliceActivity Country AvgSpeed DangerLvl  \
# 94  summer     bad      bad        regular  Europe      low       low
#
#    NoAccidents NoFatalities
# 94         low          low
# predict:  0.15721099999999666
#     Weekend Season Weather RoadCond NoJourneys Country AvgSpeed DangerLvl  \
# 95  working   fall     bad      bad     medium  Europe      low       low
#
#    NoAccidents NoFatalities
# 95         low          low
# predict:  0.1484240000000021
#     Weekend  Season Weather RoadCond PoliceActivity NoJourneys Country  \
# 96  working  spring     bad      bad        regular        low      UK
#
#    AvgSpeed DangerLvl NoAccidents
# 96      low       low        high
# predict:  0.12660800000000094
#    Season Weather RoadCond PoliceActivity NoJourneys Country AvgSpeed  \
# 97   fall     bad      bad        regular     medium  Europe      low
#
#    DangerLvl NoAccidents NoFatalities
# 97       low        high       medium
# predict:  0.16900899999999908
#      Weekend  Season Weather RoadCond PoliceActivity Country AvgSpeed  \
# 100  working  winter     bad      bad      increased      US      low
#
#     DangerLvl NoAccidents
# 100       low         low
# predict:  0.12737399999999965
#      Weekend  Season Weather RoadCond PoliceActivity NoJourneys AvgSpeed  \
# 101  working  summer    good     good        regular     medium     high
#
#     DangerLvl NoAccidents NoFatalities
# 101       low         low         high
# predict:  0.18422500000000142
#      Weekend Season Weather PoliceActivity NoJourneys Country AvgSpeed  \
# 104  working   fall    good        regular        low      US      low
#
#     DangerLvl NoAccidents NoFatalities
# 104       low         low         high
# predict:  0.13881199999999794
#      Weekend Season Weather RoadCond NoJourneys Country AvgSpeed DangerLvl  \
# 109  weekend   fall    good     good     medium  Europe      low       low
#
#     NoAccidents NoFatalities
# 109         low          low
# predict:  0.12966600000000028
#      Season Weather RoadCond PoliceActivity NoJourneys Country AvgSpeed  \
# 110  winter     bad      bad        regular        low  Europe      low
#
#     DangerLvl NoAccidents NoFatalities
# 110      high      medium       medium
# predict:  0.13613199999999992
#      Season Weather RoadCond PoliceActivity Country DangerLvl NoAccidents  \
# 111  summer    good     good        regular      UK       low         low
#
#     NoFatalities
# 111          low
# predict:  0.13105799999999945
#      Weekend  Season Weather RoadCond PoliceActivity NoJourneys Country  \
# 114  working  winter     bad      bad        regular        low  Europe
#
#     DangerLvl NoAccidents
# 114       low         low
# predict:  0.14162699999999973
#      Weekend Weather RoadCond PoliceActivity NoJourneys Country AvgSpeed  \
# 115  working    good     good        regular     medium  Europe     high
#
#     DangerLvl NoAccidents NoFatalities
# 115       low         low          low
# predict:  0.13795800000000114
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-4efc5cb79ac2> in <module>()
#      30 #         v.dropna(axis=0, inplace=True)
#      31         t0 = time.clock()
# ---> 32         value = model.predict(na_removed[k])
#      33         print(na_removed[k])
#      34         print('predict: ', time.clock() - t0)
#
# ~/miniconda3/envs/SMU/lib/python3.6/site-packages/pgmpy/models/BayesianModel.py in predict(self, data)
#     751         model_inference = VariableElimination(self, state_names=self.get_cpds()[0].state_names)
#     752         for index, data_point in data.iterrows():
# --> 753             states_dict = model_inference.map_query(variables=missing_variables, evidence=data_point.to_dict())
#     754             for k, v in states_dict.items():
#     755                 pred_values[k].append(v)
#
# ~/miniconda3/envs/SMU/lib/python3.6/site-packages/pgmpy/utils/state_name.py in __call__(self, f, instance, args, kwargs)
#     185
#     186         elif not self.arg and self.return_val:
# --> 187             return_val = f(*args, **kwargs)
#     188
#     189             mapped_return_val = self.get_mapped_value(return_val)
#
# ~/miniconda3/envs/SMU/lib/python3.6/site-packages/pgmpy/inference/ExactInference.py in map_query(self, variables, evidence, elimination_order)
#     199         final_distribution = self._variable_elimination(elimination_variables, 'maximize',
#     200                                                         evidence=evidence,
# --> 201                                                         elimination_order=elimination_order)
#     202         # To handle the case when no argument is passed then
#     203         # _variable_elimination returns a dict.
#
# ~/miniconda3/envs/SMU/lib/python3.6/site-packages/pgmpy/utils/state_name.py in __call__(self, f, instance, args, kwargs)
#     174                 arg_val = kwargs[self.arg]
#     175                 kwargs[self.arg] = self.get_mapped_value(arg_val)
# --> 176                 return f(*args, **kwargs)
#     177             # If input parameters are in args format
#     178             else:
#
# ~/miniconda3/envs/SMU/lib/python3.6/site-packages/pgmpy/inference/ExactInference.py in _variable_elimination(self, variables, operation, evidence, elimination_order)
#      48         eliminated_variables = set()
#      49         working_factors = {node: {factor for factor in self.factors[node]}
# ---> 50                            for node in self.factors}
#      51
#      52         # Dealing with evidence. Reducing factors over it before VE is run.
#
# ~/miniconda3/envs/SMU/lib/python3.6/site-packages/pgmpy/inference/ExactInference.py in <dictcomp>(.0)
#      48         eliminated_variables = set()
#      49         working_factors = {node: {factor for factor in self.factors[node]}
# ---> 50                            for node in self.factors}
#      51
#      52         # Dealing with evidence. Reducing factors over it before VE is run.
#
# ~/miniconda3/envs/SMU/lib/python3.6/site-packages/pgmpy/inference/ExactInference.py in <setcomp>(.0)
#      47
#      48         eliminated_variables = set()
# ---> 49         working_factors = {node: {factor for factor in self.factors[node]}
#      50                            for node in self.factors}
#      51
#
# ~/miniconda3/envs/SMU/lib/python3.6/site-packages/pgmpy/factors/discrete/DiscreteFactor.py in __hash__(self)
#     813                                                                       phi.cardinality[axis])
#     814             phi.values = phi.values.swapaxes(axis, exchange_index)
# --> 815         return hash(str(sorted_var_hashes) + str(phi.values) + str(phi.cardinality))
#     816
#
# ~/miniconda3/envs/SMU/lib/python3.6/site-packages/numpy/core/arrayprint.py in array_str(a, max_line_width, precision, suppress_small)
#    1462         return _guarded_str(np.ndarray.__getitem__(a, ()))
#    1463
# -> 1464     return array2string(a, max_line_width, precision, suppress_small, ' ', "")
#    1465
#    1466 def set_string_function(f, repr=True):
#
# ~/miniconda3/envs/SMU/lib/python3.6/site-packages/numpy/core/arrayprint.py in array2string(a, max_line_width, precision, suppress_small, separator, prefix, style, formatter, threshold, edgeitems, sign, floatmode, suffix, **kwarg)
#     628         return "[]"
#     629
# --> 630     return _array2string(a, options, separator, prefix)
#     631
#     632
#
# ~/miniconda3/envs/SMU/lib/python3.6/site-packages/numpy/core/arrayprint.py in wrapper(self, *args, **kwargs)
#     424             repr_running.add(key)
#     425             try:
# --> 426                 return f(self, *args, **kwargs)
#     427             finally:
#     428                 repr_running.discard(key)
#
# ~/miniconda3/envs/SMU/lib/python3.6/site-packages/numpy/core/arrayprint.py in _array2string(a, options, separator, prefix)
#     459     lst = _formatArray(a, format_function, options['linewidth'],
#     460                        next_line_prefix, separator, options['edgeitems'],
# --> 461                        summary_insert, options['legacy'])
#     462     return lst
#     463
#
# ~/miniconda3/envs/SMU/lib/python3.6/site-packages/numpy/core/arrayprint.py in _formatArray(a, format_function, line_width, next_line_prefix, separator, edge_items, summary_insert, legacy)
#     756         return recurser(index=(),
#     757                         hanging_indent=next_line_prefix,
# --> 758                         curr_width=line_width)
#     759     finally:
#     760         # recursive closures have a cyclic reference to themselves, which
#
# ~/miniconda3/envs/SMU/lib/python3.6/site-packages/numpy/core/arrayprint.py in recurser(index, hanging_indent, curr_width)
#     742             for i in range(trailing_items, 1, -1):
#     743                 nested = recurser(index + (-i,), next_hanging_indent,
# --> 744                                   next_width)
#     745                 s += hanging_indent + nested + line_sep
#     746
#
# ~/miniconda3/envs/SMU/lib/python3.6/site-packages/numpy/core/arrayprint.py in recurser(index, hanging_indent, curr_width)
#     742             for i in range(trailing_items, 1, -1):
#     743                 nested = recurser(index + (-i,), next_hanging_indent,
# --> 744                                   next_width)
#     745                 s += hanging_indent + nested + line_sep
#     746
#
# ~/miniconda3/envs/SMU/lib/python3.6/site-packages/numpy/core/arrayprint.py in recurser(index, hanging_indent, curr_width)
#     742             for i in range(trailing_items, 1, -1):
#     743                 nested = recurser(index + (-i,), next_hanging_indent,
# --> 744                                   next_width)
#     745                 s += hanging_indent + nested + line_sep
#     746
#
# ~/miniconda3/envs/SMU/lib/python3.6/site-packages/numpy/core/arrayprint.py in recurser(index, hanging_indent, curr_width)
#     742             for i in range(trailing_items, 1, -1):
#     743                 nested = recurser(index + (-i,), next_hanging_indent,
# --> 744                                   next_width)
#     745                 s += hanging_indent + nested + line_sep
#     746
#
# ~/miniconda3/envs/SMU/lib/python3.6/site-packages/numpy/core/arrayprint.py in recurser(index, hanging_indent, curr_width)
#     745                 s += hanging_indent + nested + line_sep
#     746
# --> 747             nested = recurser(index + (-1,), next_hanging_indent, next_width)
#     748             s += hanging_indent + nested
#     749
#
# ~/miniconda3/envs/SMU/lib/python3.6/site-packages/numpy/core/arrayprint.py in recurser(index, hanging_indent, curr_width)
#     742             for i in range(trailing_items, 1, -1):
#     743                 nested = recurser(index + (-i,), next_hanging_indent,
# --> 744                                   next_width)
#     745                 s += hanging_indent + nested + line_sep
#     746
#
# ~/miniconda3/envs/SMU/lib/python3.6/site-packages/numpy/core/arrayprint.py in recurser(index, hanging_indent, curr_width)
#     718                 # width of the seperator is not considered on 1.13
#     719                 elem_width = curr_width
# --> 720             word = recurser(index + (-1,), next_hanging_indent, next_width)
#     721             s, line = _extendLine(
#     722                 s, line, word, elem_width, hanging_indent, legacy)
#
# ~/miniconda3/envs/SMU/lib/python3.6/site-packages/numpy/core/arrayprint.py in recurser(index, hanging_indent, curr_width)
#     664
#     665         if axes_left == 0:
# --> 666             return format_function(a[index])
#     667
#     668         # when recursing, add a space to align with the [ added, and reduce the
#
# ~/miniconda3/envs/SMU/lib/python3.6/site-packages/numpy/core/arrayprint.py in __call__(self, x)
#     910                                       sign=self.sign == '+',
#     911                                       pad_left=self.pad_left,
# --> 912                                       pad_right=self.pad_right)
#     913
#     914 # for back-compatibility, we keep the classes for each float type too
#
# KeyboardInterrupt:

# %%
filling
# Out:
#      Weekend  Season Weather RoadCond PoliceActivity NoJourneys Country  \
# 0    holiday    fall    good     good        regular        low      UK
# 1    weekend    fall     bad      bad        regular     medium  Europe
# 3    weekend  spring     bad     good        regular     medium      UK
# 8    weekend  winter     bad      bad        regular     medium      UK
# 9    weekend    fall    good      bad        regular        low  Europe
# 11   working    fall    good     good      increased     medium      US
# 18   weekend  winter     bad      bad        regular        low      US
# 27   weekend  winter     bad      bad      increased        low      UK
# 31   weekend  summer    good     good        regular     medium      US
# 33   weekend    fall     bad      bad        regular        low  Europe
# 37   working  spring    good     good        regular        low  Europe
# 39   working  spring    good     good        regular     medium      UK
# 44   working  winter    good     good      increased        low      US
# 45   working    fall     bad      bad        regular        low  Europe
# 48   holiday    fall     bad      bad      increased        low      US
# 49   working    fall     bad      bad        regular        low  Europe
# 51   weekend  summer    good     good        regular     medium  Europe
# 54   working  spring    good      bad        regular        low      US
# 56   weekend    fall     bad      bad        regular        low      US
# 58   working  summer    good     good        regular     medium      UK
# 60   holiday  winter    good      bad      increased     medium  Europe
# 62   working    fall    good     good        regular     medium  Europe
# 63   working  winter     bad      bad        regular        low  Europe
# 64   working  summer    good      bad        regular        low      US
# 69   working  spring    good      bad        regular        low  Europe
# 70   holiday    fall    good     good        regular     medium      UK
# 72   working  summer    good     good        regular     medium      UK
# 76   working  winter     bad      bad        regular        low      US
# 77   working  spring     bad      bad      increased     medium  Europe
# 79   holiday    fall    good     good        regular     medium  Europe
# ..       ...     ...     ...      ...            ...        ...     ...
# 175  working  spring    good      bad        regular        low      US
# 177  holiday  spring    good     good        regular        low  Europe
# 178  working  summer    good      bad        regular     medium  Europe
# 181  working  winter    good     good        regular        low  Europe
# 182  weekend    fall    good     good        regular     medium      UK
# 184  working  summer    good     good      increased        low  Europe
# 185  holiday  summer     bad     good      increased     medium  Europe
# 187  working  summer    good     good        regular     medium  Europe
# 188  holiday    fall     bad      bad      increased        low  Europe
# 189  weekend  spring     bad      bad      increased        low      US
# 191  weekend  spring    good     good      increased     medium  Europe
# 192  weekend    fall     bad     good        regular        low      US
# 193  weekend  winter     bad      bad      increased        low  Europe
# 194  holiday  summer     bad     good        regular     medium  Europe
# 195  working  winter     bad      bad        regular     medium      UK
# 199  weekend    fall    good      bad      increased     medium  Europe
# 200  holiday    fall    good     good        regular     medium  Europe
# 202  working    fall    good      bad        regular        low      US
# 204  working  winter     bad      bad        regular     medium      US
# 205  weekend  winter    good     good      increased     medium  Europe
# 208  holiday  summer     bad      bad        regular        low      US
# 209  weekend  winter    good     good        regular     medium  Europe
# 211  working    fall    good     good      increased     medium  Europe
# 212  working  summer     bad      bad      increased     medium      UK
# 213  weekend  winter     bad      bad        regular        low      UK
# 214  working  winter     bad      bad        regular     medium  Europe
# 215  working  winter     bad      bad        regular     medium      US
# 216  weekend  spring    good      bad        regular     medium      US
# 218  working    fall    good      bad        regular        low  Europe
# 219  working  summer    good     good        regular     medium      UK
#
#     AvgSpeed DangerLvl NoAccidents NoFatalities
# 0       high       low        high       medium
# 1        low       low      medium          low
# 3       high       low         low          low
# 8        low       low         low         high
# 9        low      high         low       medium
# 11      high      high         low          low
# 18       low      high      medium          low
# 27       low       low      medium         high
# 31       low       low        high          low
# 33      high       low         low          low
# 37      high      high        high          low
# 39      high       low         low          low
# 44       low       low         low          low
# 45       low       low        high          low
# 48      high       low         low          low
# 49       low       low      medium         high
# 51      high       low         low          low
# 54      high      high      medium         high
# 56       low       low         low          low
# 58      high      high         low       medium
# 60       low       low         low         high
# 62      high       low      medium          low
# 63       low       low         low          low
# 64       low      high         low          low
# 69       low       low         low         high
# 70      high       low      medium         high
# 72      high       low      medium         high
# 76      high       low         low       medium
# 77       low       low         low       medium
# 79      high       low         low         high
# ..       ...       ...         ...          ...
# 175     high       low        high          low
# 177     high       low         low          low
# 178     high       low      medium       medium
# 181      low       low         low       medium
# 182     high       low      medium          low
# 184     high       low      medium         high
# 185      low       low      medium         high
# 187     high       low         low         high
# 188     high       low      medium         high
# 189      low       low         low       medium
# 191     high       low         low          low
# 192     high       low      medium       medium
# 193      low       low         low          low
# 194     high       low         low          low
# 195     high       low      medium       medium
# 199      low       low         low          low
# 200     high       low        high       medium
# 202      low       low        high       medium
# 204      low       low         low         high
# 205     high       low        high          low
# 208      low      high         low          low
# 209      low       low      medium          low
# 211      low       low      medium         high
# 212      low       low         low          low
# 213     high       low         low          low
# 214      low       low        high       medium
# 215     high       low        high         high
# 216      low       low         low       medium
# 218      low       low        high          low
# 219     high       low      medium         high
#
# [100 rows x 11 columns]

# %%
model = BayesianModel(connections)
model.fit(data, estimator=BayesianEstimator, prior_type="BDeu")
# train_data.drop(train_data.columns[0], axis=1, inplace=True)
first_row = test_data.copy().head(1)
idx = first_row.isnull()
first_row.dropna(axis=1, inplace=True)
val = model.predict(first_row)
# print(val)
# print(idx)
# print(first_row)
first = test_data.head(1).copy()

for k,v in idx.items():
    print(k)
    if v[0]:
        first.at[0, k] = val
print(first)

# print(model.is_active_trail('Season', 'NoFatalities'))
# print(model.is_active_trail('Weather', 'NoAccidents', 'RoadCond'))
# print(model.is_active_trail('Season', 'Weekend', 'NoAccidents'))

# for c in connections:
#     for c2 in connections:
#         if c == c2:
#             continue
#         print(model.is_active_trail(c[0],c2[0]), c[0], c2[0])
# Out:
# Weekend
# Season
# Weather
# RoadCond
# PoliceActivity
# NoJourneys
# Country
# AvgSpeed
# DangerLvl
# NoAccidents
# NoFatalities
#    Weekend Season Weather RoadCond PoliceActivity NoJourneys Country  \
# 0  holiday   fall    good     good        regular        low      UK
#
#                 AvgSpeed DangerLvl NoAccidents NoFatalities
# 0    AvgSpeed
# 0      low       low        high       medium

# %%
import numpy as np
import pandas as pd
from pgmpy.models import BayesianModel
values = pd.DataFrame(np.random.randint(low=0, high=2, size=(1000, 5)),
                      columns=['A', 'B', 'C', 'D', 'E'])
train_data = values[:800]

predict_data = values[800:]
model = BayesianModel([('A', 'B'), ('C', 'B'), ('C', 'D'), ('B', 'E')])
model.fit(values)
predict_data = predict_data.copy()
predict_data.drop('E', axis=1, inplace=True)
y_pred = model.predict(predict_data)
y_pred
# Out:
#      E
# 800  0
# 801  0
# 802  0
# 803  1
# 804  1
# 805  0
# 806  1
# 807  0
# 808  1
# 809  1
# 810  1
# 811  0
# 812  1
# 813  1
# 814  1
# 815  1
# 816  0
# 817  1
# 818  0
# 819  0
# 820  1
# 821  0
# 822  1
# 823  0
# 824  1
# 825  0
# 826  1
# 827  0
# 828  0
# 829  1
# ..  ..
# 970  1
# 971  1
# 972  1
# 973  0
# 974  0
# 975  0
# 976  1
# 977  1
# 978  1
# 979  0
# 980  1
# 981  0
# 982  0
# 983  1
# 984  0
# 985  1
# 986  1
# 987  0
# 988  0
# 989  0
# 990  1
# 991  1
# 992  0
# 993  1
# 994  0
# 995  0
# 996  1
# 997  0
# 998  0
# 999  0
#
# [200 rows x 1 columns]

# %%
fat = 'NoFatalities'
# pe = ParameterEstimator(model, data)
# print(pe.state_counts(fat))

# mle = MaximumLikelihoodEstimator(model, data) #.sample(200)
# print(mle.estimate_cpd(fat))
# model.fit(data, estimator=BayesianEstimator, prior_type="BDeu")
# model.get_independencies()
# cpds = model.get_cpds()
model.predict(test_data)

# print(len(cpds))
# print(cpds[6])

# for cpd in cpds:
#     cpd.
#     print(cpd.get_values())


# q = mle.estimate_cpd(fat)
# be = BayesianEstimator(model, data)
# print(be.estimate_cpd('NoFatalities',prior_type='BDeu', equivalent_sample_size=10))

# print(q.get_values())
# flat = [x for sublist in q.get_values() for x in sublist]

# from pgmpy.factors.discrete import JointProbabilityDistribution as JPD
# prob = JPD(q.variables, q.cardinality, q.get_values())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-279-42f54cb7624e> in <module>()
#       9 # model.get_independencies()
#      10 # cpds = model.get_cpds()
# ---> 11 model.predict(test_data)
#      12
#      13 # print(len(cpds))
#
# ~/.local/miniconda3/lib/python3.6/site-packages/pgmpy/models/BayesianModel.py in predict(self, data)
#     743
#     744         elif set(data.columns) - set(self.nodes()):
# --> 745             raise ValueError("Data has variables which are not in the model")
#     746
#     747         missing_variables = set(self.nodes()) - set(data.columns)
#
# ValueError: Data has variables which are not in the model
